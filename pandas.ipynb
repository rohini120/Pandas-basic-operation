# %%
import pandas as pd

# %%
data=pd.read_csv(r"C:\Users\guddi\Desktop\doc\irisdata.csv")

# %%
#head of data

data.head()
# Out:
#    5.1  3.5  1.4  0.2  Iris-setosa
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
#column name are not specify so we have to give names
#naming columns

data.columns = ['SepalLengthCm','SepalWidthCm','PetalLenghtCm','PetalWidth','Species']

# %%
data.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth      Species
# 0            4.9           3.0            1.4         0.2  Iris-setosa
# 1            4.7           3.2            1.3         0.2  Iris-setosa
# 2            4.6           3.1            1.5         0.2  Iris-setosa
# 3            5.0           3.6            1.4         0.2  Iris-setosa
# 4            5.4           3.9            1.7         0.4  Iris-setosa

# %%
#tail of data

data.tail()
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth         Species
# 144            6.7           3.0            5.2         2.3  Iris-virginica
# 145            6.3           2.5            5.0         1.9  Iris-virginica
# 146            6.5           3.0            5.2         2.0  Iris-virginica
# 147            6.2           3.4            5.4         2.3  Iris-virginica
# 148            5.9           3.0            5.1         1.8  Iris-virginica

# %%
#shape of data

data.shape
# Out:
# (149, 5)

# %%
#iteration through rows
#:5 this means 1st 5 rows, :4 this means 1st 4 columns
data.iloc[:5,:4]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth
# 0            4.9           3.0            1.4         0.2
# 1            4.7           3.2            1.3         0.2
# 2            4.6           3.1            1.5         0.2
# 3            5.0           3.6            1.4         0.2
# 4            5.4           3.9            1.7         0.4

# %%
#index of dataset

data.index
# Out:
# RangeIndex(start=0, stop=149, step=1)

# %%
data.iloc[3:6,:-1]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth
# 3            5.0           3.6            1.4         0.2
# 4            5.4           3.9            1.7         0.4
# 5            4.6           3.4            1.4         0.3

# %%
data.iloc[5:8,1:3]
# Out:
#    SepalWidthCm  PetalLenghtCm
# 5           3.4            1.4
# 6           3.4            1.5
# 7           2.9            1.4

# %%
#getting rows by specific conditions

data.loc[data['SepalLengthCm'] >= 5.0]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth         Species
# 3              5.0           3.6            1.4         0.2     Iris-setosa
# 4              5.4           3.9            1.7         0.4     Iris-setosa
# 6              5.0           3.4            1.5         0.2     Iris-setosa
# 9              5.4           3.7            1.5         0.2     Iris-setosa
# 13             5.8           4.0            1.2         0.2     Iris-setosa
# ..             ...           ...            ...         ...             ...
# 144            6.7           3.0            5.2         2.3  Iris-virginica
# 145            6.3           2.5            5.0         1.9  Iris-virginica
# 146            6.5           3.0            5.2         2.0  Iris-virginica
# 147            6.2           3.4            5.4         2.3  Iris-virginica
# 148            5.9           3.0            5.1         1.8  Iris-virginica
#
# [127 rows x 5 columns]

# %%
data.loc[data['Species'] == 'Iris-virginica']
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth         Species
# 99             6.3           3.3            6.0         2.5  Iris-virginica
# 100            5.8           2.7            5.1         1.9  Iris-virginica
# 101            7.1           3.0            5.9         2.1  Iris-virginica
# 102            6.3           2.9            5.6         1.8  Iris-virginica
# 103            6.5           3.0            5.8         2.2  Iris-virginica
# 104            7.6           3.0            6.6         2.1  Iris-virginica
# 105            4.9           2.5            4.5         1.7  Iris-virginica
# 106            7.3           2.9            6.3         1.8  Iris-virginica
# 107            6.7           2.5            5.8         1.8  Iris-virginica
# 108            7.2           3.6            6.1         2.5  Iris-virginica
# 109            6.5           3.2            5.1         2.0  Iris-virginica
# ...

# %%
#to describe the data

data.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth
# count     149.000000    149.000000     149.000000  149.000000
# mean        5.848322      3.051007       3.774497    1.205369
# std         0.828594      0.433499       1.759651    0.761292
# min         4.300000      2.000000       1.000000    0.100000
# 25%         5.100000      2.800000       1.600000    0.300000
# 50%         5.800000      3.000000       4.400000    1.300000
# 75%         6.400000      3.300000       5.100000    1.800000
# max         7.900000      4.400000       6.900000    2.500000

# %%
#By passing include=['object'] shows information about catogorical variable

data.describe(include=['object'])
# Out:
#                 Species
# count               149
# unique                3
# top     Iris-versicolor
# freq                 50

# %%
#to sort the data

data.sort_values('SepalLengthCm', ascending=False)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth         Species
# 130            7.9           3.8            6.4         2.0  Iris-virginica
# 134            7.7           3.0            6.1         2.3  Iris-virginica
# 121            7.7           2.8            6.7         2.0  Iris-virginica
# 116            7.7           3.8            6.7         2.2  Iris-virginica
# 117            7.7           2.6            6.9         2.3  Iris-virginica
# ..             ...           ...            ...         ...             ...
# 40             4.5           2.3            1.3         0.3     Iris-setosa
# 7              4.4           2.9            1.4         0.2     Iris-setosa
# 41             4.4           3.2            1.3         0.2     Iris-setosa
# 37             4.4           3.0            1.3         0.2     Iris-setosa
# 12             4.3           3.0            1.1         0.1     Iris-setosa
#
# [149 rows x 5 columns]

# %%
data.sort_values(['SepalLengthCm', 'PetalLenghtCm'], ascending=False)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth         Species
# 130            7.9           3.8            6.4         2.0  Iris-virginica
# 117            7.7           2.6            6.9         2.3  Iris-virginica
# 116            7.7           3.8            6.7         2.2  Iris-virginica
# 121            7.7           2.8            6.7         2.0  Iris-virginica
# 134            7.7           3.0            6.1         2.3  Iris-virginica
# ..             ...           ...            ...         ...             ...
# 40             4.5           2.3            1.3         0.3     Iris-setosa
# 7              4.4           2.9            1.4         0.2     Iris-setosa
# 37             4.4           3.0            1.3         0.2     Iris-setosa
# 41             4.4           3.2            1.3         0.2     Iris-setosa
# 12             4.3           3.0            1.1         0.1     Iris-setosa
#
# [149 rows x 5 columns]

# %%
#aggregate statistics
#Mean value of each columns groupby Species

data.groupby(['Species']).mean()
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth
# Species
# Iris-setosa           5.004082      3.416327       1.465306    0.244898
# Iris-versicolor       5.936000      2.770000       4.260000    1.326000
# Iris-virginica        6.588000      2.974000       5.552000    2.026000

# %%
#sum of each column groupby species

data.groupby(['Species']).sum()
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth
# Species
# Iris-setosa              245.2         167.4           71.8        12.0
# Iris-versicolor          296.8         138.5          213.0        66.3
# Iris-virginica           329.4         148.7          277.6       101.3

# %%
data.groupby(['Species']).count()
# Out:
#                  SepalLengthCm  SepalWidthCm  PetalLenghtCm  PetalWidth
# Species
# Iris-setosa                 49            49             49          49
# Iris-versicolor             50            50             50          50
# Iris-virginica              50            50             50          50
